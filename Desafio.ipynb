# %% [markdown]
# # Desafio Análise de Dados Indicium

# %% [markdown]
# ### **1. Configuração de ambiente e carregamento dos dados**
# 1.1. Caso as bibliotecas *Pandas, Matplotlib, Seaborn* não estejam incluídas na distribuição padrão do Python ou não estejam instaladas localmente, executar o comando pip install + biblioteca. Caso contrário, seguir para a importação

# %%
#Importar as bibliotecas (usar comando pip install, caso não estejam instaladas)
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Carregar os dados do arquivo ZIP
banvic_data = pd.read_csv('../Projeto/dados/banvic_data/agencias.csv')

# %%
# Visualizar as primeiras linhas dos dados
banvic_data.head()
# Out:
#    cod_agencia              nome  \
# 0            7   Agência Digital
# 1            1    Agência Matriz
# 2            2   Agência Tatuapé
# 3            3  Agência Campinas
# 4            4    Agência Osasco
#
#                                             endereco     cidade  uf  \
# 0  Av. Paulista, 1436 - Cerqueira César, São Paul...  São Paulo  SP
# 1  Av. Paulista, 1436 - Cerqueira César, São Paul...  São Paulo  SP
# 2  Praça Sílvio Romero, 158 - Tatuapé, São Paulo ...  São Paulo  SP
# 3  Av. Francisco Glicério, 895 - Vila Lidia, Camp...   Campinas  SP
# 4  Av. Antônio Carlos Costa, 1000 - Bela Vista, O...     Osasco  SP
#
#   data_abertura tipo_agencia
# 0    2015-08-01      Digital
# 1    2010-01-01       Física
# 2    2010-06-14       Física
# 3    2012-03-04       Física
# 4    2013-11-06       Física

# %% [markdown]
# ### **2. Limpeza de Dados**
# Verificar e tratar valores ausentes (NaN) com `df.isnull().sum()` e `df.dropna()` ou `df.fillna()`.
#
# O método `dropna()` é usado para remover linhas com valores ausentes e `fillna(0)` para preencher valores ausentes com zero. No caso do presente dataset, não foi necessário, já que não tem objetos nulos.
# Os passos vistos até aqui para o primeiro dataset, vão ser replicados para os outros arquivos csv.

# %%
# Exibir informações básicas sobre os dados
print("Informações sobre os dados:")
print(banvic_data.info())
#nao tem objetos nulos: 10 entradas, 10 não nulos
# Out:
# Informações sobre os dados:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   cod_agencia    10 non-null     int64
#  1   nome           10 non-null     object
#  2   endereco       10 non-null     object
#  3   cidade         10 non-null     object
#  4   uf             10 non-null     object
#  5   data_abertura  10 non-null     object
#  6   tipo_agencia   10 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 692.0+ bytes
# None

# %%
#Verificando a data de abertura das agências
banvic_data['data_abertura']
# Out:
# 0    2015-08-01
# 1    2010-01-01
# 2    2010-06-14
# 3    2012-03-04
# 4    2013-11-06
# 5    2013-12-01
# 6    2015-04-01
# 7    2018-01-09
# 8    2019-10-09
# 9    2021-10-09
# Name: data_abertura, dtype: object

# %%
""" # Converter a coluna 'Data_Abertura_Conta' para o tipo datetime
banvic_data['data_abertura'] = pd.to_datetime(banvic_data['data_abertura'])

# Verificar o tipo de dados após a conversão
print(banvic_data.info())

# Criar o gráfico de dispersão
plt.figure(figsize=(12, 8))
for agencia in banvic_data['nome'].unique():
    data_agencia = banvic_data[banvic_data['nome'] == agencia]['data_abertura']
    plt.plot(data_agencia, [agencia] * len(data_agencia), marker='o', linestyle='', label=f'Agência {agencia}')

plt.title('Abertura de Conta por Agência e ano')
plt.xlabel('Ano abertura')
plt.ylabel('Agência')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show() """
# Out:
# " # Converter a coluna 'Data_Abertura_Conta' para o tipo datetime\nbanvic_data['data_abertura'] = pd.to_datetime(banvic_data['data_abertura'])\n\n# Verificar o tipo de dados após a conversão\nprint(banvic_data.info())\n\n# Criar o gráfico de dispersão\nplt.figure(figsize=(12, 8))\nfor agencia in banvic_data['nome'].unique():\n    data_agencia = banvic_data[banvic_data['nome'] == agencia]['data_abertura']\n    plt.plot(data_agencia, [agencia] * len(data_agencia), marker='o', linestyle='', label=f'Agência {agencia}')\n\nplt.title('Abertura de Conta por Agência e ano')\nplt.xlabel('Ano abertura')\nplt.ylabel('Agência')\nplt.legend()\nplt.grid(True)\nplt.tight_layout()\nplt.show() "

# %%
""" # Criar uma lista de dicionários para armazenar os resultados
contas_por_mes = []

# Iterar sobre todos os meses
for mes in range(1, 13):
    contas_mes = banvic_data[banvic_data['data_abertura'].dt.month == mes]
    num_contas_mes = len(contas_mes)
    # Adicionar um dicionário representando uma nova linha à lista
    contas_por_mes.extend([{'Mes': mes, 'Numero_Contas': num_contas_mes}])

# Criar um DataFrame a partir da lista de dicionários
contas_por_mes_df = pd.DataFrame(contas_por_mes)

# Exibir o DataFrame resultante
print(contas_por_mes_df) """
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 6
#       4 # Iterar sobre todos os meses
#       5 for mes in range(1, 13):
# ----> 6     contas_mes = banvic_data[banvic_data['data_abertura'].dt.month == mes]
#       7     num_contas_mes = len(contas_mes)
#       8     # Adicionar um dicionário representando uma nova linha à lista
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# ...

# %%
# Carregar os dados do arquivo ZIP
# Certifique-se de extrair o conteúdo do arquivo ZIP antes de executar este script
banvic_data_client = pd.read_csv('../Projeto/dados/banvic_data/clientes.csv')

# %%
banvic_data_client.head()
# Out:
#    cod_cliente primeiro_nome ultimo_nome                         email  \
# 0           28       Sabrina        Dias  moreiraemanuelly@example.org
# 1          674   Luiz Felipe        Dias     pedroferreira@example.org
# 2          693         Renan        Dias            ogomes@example.net
# 3          743         Clara        Dias     rafaelcorreia@example.org
# 4          769         André        Dias          danilo33@example.org
#
#   tipo_cliente            data_inclusao         cpfcnpj data_nascimento  \
# 0           PF  2017-04-03 16:11:00 UTC  357.081.496-39      2006-08-11
# 1           PF  2021-02-10 13:27:00 UTC  085.196.374-93      1995-10-11
# 2           PF  2020-01-21 13:12:00 UTC  783.416.059-10      1948-11-19
# 3           PF  2019-05-06 11:39:00 UTC  589.237.610-95      1978-01-27
# 4           PF  2017-01-07 14:53:00 UTC  459.608.721-02      1990-08-25
#
#                                             endereco        cep
# ...

# %%
banvic_data_client.info()
#script de limpeza
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998 entries, 0 to 997
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   cod_cliente      998 non-null    int64
#  1   primeiro_nome    998 non-null    object
#  2   ultimo_nome      998 non-null    object
#  3   email            998 non-null    object
#  4   tipo_cliente     998 non-null    object
#  5   data_inclusao    998 non-null    object
#  6   cpfcnpj          998 non-null    object
#  7   data_nascimento  998 non-null    object
#  8   endereco         998 non-null    object
#  9   cep              998 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 78.1+ KB

# %%
# Converter a coluna 'Data_Abertura_Conta' para o tipo datetime
banvic_data_client['data_inclusao'] = pd.to_datetime(banvic_data_client['data_inclusao'])

# Verificar o tipo de dados após a conversão
print(banvic_data_client.info())

# Criar o gráfico de dispersão
plt.figure(figsize=(12, 8))
for agencia in banvic_data_client['cod_client'].unique():
    data_agencia = banvic_data[banvic_data['cod_client'] == agencia]['data_inclusao']
    plt.plot(data_agencia, [agencia] * len(data_agencia), marker='o', linestyle='', label=f'Agência {agencia}')

plt.title('Abertura de Conta por Agência e ano')
plt.xlabel('Ano abertura')
plt.ylabel('Agência')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998 entries, 0 to 997
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   cod_cliente      998 non-null    int64
#  1   primeiro_nome    998 non-null    object
#  2   ultimo_nome      998 non-null    object
#  3   email            998 non-null    object
#  4   tipo_cliente     998 non-null    object
#  5   data_inclusao    998 non-null    datetime64[ns, UTC]
#  6   cpfcnpj          998 non-null    object
#  7   data_nascimento  998 non-null    object
#  8   endereco         998 non-null    object
#  9   cep              998 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(1), object(8)
# memory usage: 78.1+ KB
# None
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#fazer scrip juntar clientes + agencia
código cliente

# %%
#Verificando os ceps existentes 
banvic_data_client['cep'].unique()
# Out:
# array(['95140-704', '76516-765', '51779625', '19615792', '01672838',
#        '07814-131', '90221-380', '44875-244', '42603-833', '23176352',
#        '96027-142', '29942-354', '97628-818', '57113-154', '26119706',
#        '80317732', '77226042', '12716-003', '37988-526', '16954952',
#        '51092202', '96975888', '73739-486', '50832-820', '77360-182',
#        '51214338', '49990438', '84504002', '63158375', '69025958',
#        '05254-597', '04065275', '47546-871', '88422-547', '87868-132',
#        '67750-393', '30314554', '75462082', '11965-789', '14157-016',
#        '26941177', '88078064', '02434042', '25512578', '98200059',
#        '31500163', '18876-575', '86294-895', '38071-009', '38180255',
#        '89813224', '98259-386', '67484257', '07873-123', '56424-819',
#        '81473-142', '19744436', '74907782', '07845-704', '11168371',
#        '43803139', '50946020', '37183-556', '03481410', '70396-535',
# ...

# %%
#banvic_data_client['data_abertura']
banvic_data_client['tipo_cliente'].value_counts()
# Out:
# tipo_cliente
# PF    998
# Name: count, dtype: int64

# %%
banvic_data_contas = pd.read_csv('../Projeto/dados/banvic_data/contas.csv')
banvic_data_contas.head()
# Out:
#    num_conta  cod_cliente  cod_agencia  cod_colaborador tipo_conta  \
# 0         53           53            1                7         PF
# 1        190          190            1                7         PF
# 2        191          191            1                7         PF
# 3        203          203            1                7         PF
# 4        254          254            1                7         PF
#
#              data_abertura  saldo_total  saldo_disponivel  \
# 0  2011-05-24 15:30:00 UTC    2984.7615           2814.67
# 1  2014-10-17 14:48:00 UTC    4262.4322           4191.86
# 2  2013-03-23 14:14:00 UTC    3266.5680           3080.71
# 3  2016-08-03 16:13:00 UTC   21241.5424          19461.56
# 4  2012-10-24 13:48:00 UTC   13335.6966          13197.54
#
#     data_ultimo_lancamento
# 0  2019-07-02 11:03:46 UTC
# 1  2021-03-25 12:00:15 UTC
# 2  2016-09-09 23:34:15 UTC
# 3  2022-12-28 07:58:24 UTC
# 4  2013-12-20 22:20:00 UTC

# %%
#verificando quantas contas abertas temos em cada agencia
banvic_data_contas['cod_agencia'].value_counts()
# Out:
# cod_agencia
# 7     460
# 1     119
# 2     101
# 3      76
# 4      65
# 5      61
# 6      52
# 8      30
# 9      30
# 10      5
# Name: count, dtype: int64

# %%
tabela_final_df = pd.merge(banvic_data_contas[['cod_agencia', 'cod_cliente', 'data_abertura']], 
                           banvic_data[['cod_agencia']], 
                           on='cod_agencia', 
                           how='inner')

print(tabela_final_df)
# Out:
#      cod_agencia  cod_cliente            data_abertura
# 0              1           53  2011-05-24 15:30:00 UTC
# 1              1          190  2014-10-17 14:48:00 UTC
# 2              1          191  2013-03-23 14:14:00 UTC
# 3              1          203  2016-08-03 16:13:00 UTC
# 4              1          254  2012-10-24 13:48:00 UTC
# ..           ...          ...                      ...
# 994           10          466  2022-10-26 14:13:00 UTC
# 995           10          764  2022-09-08 11:06:00 UTC
# 996           10          488  2022-07-16 10:16:00 UTC
# 997           10          395  2022-12-01 15:27:00 UTC
# 998           10          355  2022-10-22 14:50:00 UTC
#
# [999 rows x 3 columns]

# %%
banvic_data_contas['data_abertura']
